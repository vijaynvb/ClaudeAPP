# %% [markdown]
# REST API invocaton
# Antropic SDK
#
# Secreet key

# %%
# %%capture

# %pip install anthropic python-dotenv

# %%
import os
from anthropic import Anthropic
from dotenv import load_dotenv

load_dotenv()  # Load environment variables from .env file

client = Anthropic(
    api_key=os.environ.get("ANTHROPIC_API_KEY"),  # This is the default and can be omitted
)

message = client.messages.create(
    max_tokens=1024, # max tokens to be generated by the model 
    messages=[
        {
            "role": "user",
            "content": "Hello, Claude",
        }
    ],

    model="claude-opus-4-6",
)

print(message.content)
# Out:
# Message(id='msg_011Ce8RdkvB8rKS9bvuQvRRd', container=None, content=[TextBlock(citations=None, text='Hello! Welcome! How are you doing today? Is there anything I can help you with? 😊', type='text')], model='claude-opus-4-6', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=10, output_tokens=25, output_tokens_details=None, server_tool_use=None, service_tier='standard'))

# %%
print(message.content[0].text)
# Out:
# Hello! Welcome! How are you doing today? Is there anything I can help you with? 😊

# %%
for model in client.models.list():
    print(model.id, "-", model.display_name)
# Out:
# claude-opus-5 - Claude Opus 5
# claude-sonnet-5 - Claude Sonnet 5
# claude-fable-5 - Claude Fable 5
# claude-opus-4-8 - Claude Opus 4.8
# claude-opus-4-7 - Claude Opus 4.7
# claude-sonnet-4-6 - Claude Sonnet 4.6
# claude-opus-4-6 - Claude Opus 4.6
# claude-opus-4-5-20251101 - Claude Opus 4.5
# claude-haiku-4-5-20251001 - Claude Haiku 4.5
# claude-sonnet-4-5-20250929 - Claude Sonnet 4.5

# %%
message = client.messages.create(
    max_tokens=1024, # max tokens to be generated by the model 
    messages=[
        {
            "role": "user",
            "content": "Hello, Claude",
        }
    ],

    model="claude-haiku-4-5",
)

print(message.content)
# Out:
# [TextBlock(citations=None, text="Hello! It's nice to meet you. How can I help you today?", type='text')]

# %%
message = client.messages.create(
    max_tokens=1024, # max tokens to be generated by the model 
    messages=[
        {
            "role": "user",
            "content": "Hello, my name is vijay",
        },
        {
            "role": "assistant",
            "content": "Hello!  vijay It's nice to meet you. How can I help you today?"
        },
        {
            "role": "user",
            "content": "what is 1+1",
        },
        {
            "role": "assistant",
            "content": "2"
        },
        {
            "role": "user",
            "content": "what is my name",
        }
    ], # context window 272k, 1M 

    model="claude-haiku-4-5-20251001",
)

print(message.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 message = client.messages.create(
#       2     max_tokens=1024, # max tokens to be generated by the model
#       3     messages=[
#       4         {
#
# File ~/Desktop/UST_Global/ClaudeAPP/.myenv/lib/python3.13/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# ...
