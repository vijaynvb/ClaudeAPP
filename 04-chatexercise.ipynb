# %%
# Install dependencies

# %pip install anthropic python-dotenv
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
def add_message(messages, content, role):
    message = {"role": role, "content": content}
    messages.append(message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages, # user and assitant messages
        tools = [],
        system_prompt = "You are a helpful assistant that translates English to French.",
        temperature= 0, # 0 [more specific, Deterministic] - 1 [Diversified, creative],
        top_k = 5,
        top_p= .9
    )
    return next(block.text for block in message.content if block.type == "text")

# %%
# Make an initial list of messages
messages = []

# Use a 'while True' loop to run the chatbot forever
while True:
    # Get user input
    user_input = input("> ")
    print(">", user_input)

    # Add it to a list of messages
    add_message(messages, user_input, role="user")

    # Call the API
    answer = chat(messages)
    
    # Add generated text to the list messages
    add_message(messages, answer, role="assistant")

    # Print the generated text
    print("---")
    print(answer)
    print("---")
# Out:
# > hello my name is vijay
# ---
# Hello Vijay! Nice to meet you. How can I help you today?
# ---
# > what is 1+1
# ---
# 1 + 1 = 2
# ---
# > what is my name
# ---
# Your name is Vijay, as you told me at the beginning of our conversation.
# ---
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[7], line 14
#      10     # Add it to a list of messages
#      11     add_message(messages, user_input, role="user")
#      12
#      13     # Call the API
# ---> 14     answer = chat(messages)
#      15
#      16     # Add generated text to the list messages
#      17     add_message(messages, answer, role="assistant")
#
# Cell In[6], line 6, in chat(messages)
#       5 def chat(messages):
# ----> 6     message = client.messages.create(
#       7         model=model,
#       8         max_tokens=1000,
#       9         messages=messages,
#
# ...
