# %%
# Install dependencies

# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in ./.myenv/lib/python3.13/site-packages (0.121.0)
# Requirement already satisfied: python-dotenv in ./.myenv/lib/python3.13/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.myenv/lib/python3.13/site-packages (from anthropic) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.myenv/lib/python3.13/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in ./.myenv/lib/python3.13/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./.myenv/lib/python3.13/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.myenv/lib/python3.13/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.myenv/lib/python3.13/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio<2,>=1 in ./.myenv/lib/python3.13/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in ./.myenv/lib/python3.13/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in ./.myenv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in ./.myenv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in ./.myenv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.myenv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.myenv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./.myenv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.myenv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.4)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv
 
load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic
 
client = Anthropic()
model = "claude-sonnet-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    
    if system:
        params["system"] = system

    # rest api call happen here only [url + body] - server is stateless [cache] 
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Low temperature - more predictable
messages = []

add_user_message(
    messages,
    "Generate a one sentence movie idea",
)

answer = chat(messages, temperature=0, system="")

answer
# Out:
# 'A retired astronaut discovers her childhood imaginary friend was actually an alien who has returned to warn her that Earth is about to pass through a cosmic phenomenon that will make all imaginary friends become real.'

# %%
# High temperature - more creative

messages = []

add_user_message(
    messages,
    "Generate a one sentence movie idea",
)

answer = chat(messages, temperature=1.0)

answer
# Out:
# "A grieving astronaut discovers that the mysterious signal she's been tracking from deep space is actually her own voice from the future, warning her not to return to Earth."
